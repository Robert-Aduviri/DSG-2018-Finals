# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from tqdm import tqdm, tqdm_notebook
from pathlib import Path
# pd.set_option('display.max_columns', 1000)
# pd.set_option('display.max_rows', 400)
sns.set()

os.chdir('../..')

DATA = Path('data')
RAW  = DATA/'raw'
PROCESSED = DATA/'processed'
SUBMISSIONS = DATA/'submissions'

# %%
train_session         = pd.read_csv(f'{RAW}/train_session.csv', low_memory=False)
train_tracking        = pd.read_csv(f'{RAW}/train_tracking.csv', low_memory=False)
test_tracking         = pd.read_csv(f'{RAW}/test_tracking.csv', low_memory=False)
productid_category    = pd.read_csv(f'{RAW}/productid_category.csv', low_memory=False)
random_submission     = pd.read_csv(f'{RAW}/random_submission.csv', low_memory=False)

# %%
print(train_tracking.shape)
train_tracking.head()
# Out:
# (1355095, 31)
#                                                  sid      type query  \
# 0  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 1  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 2  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 3  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 4  KeKjpi6re4QRYxl76E8sLPJHxRCeapb4sb69s5hmPCV+Jn...        PA   NaN
#
#    nb_query_terms  rcount  pn facets products dproducts    rh  \
# 0             NaN     NaN NaN    NaN      NaN       NaN  1094
# 1             NaN     NaN NaN    NaN      NaN       NaN  1094
# 2             NaN     NaN NaN    NaN      NaN       NaN  1094
# 3             NaN     NaN NaN    NaN      NaN       NaN  1094
# 4             NaN     NaN NaN    NaN      NaN       NaN   875
#
#         ...         ocarproducts oquery orcount ofacets opn odproducts  \
# 0       ...                  NaN    NaN     NaN     NaN NaN        NaN
# ...

# %%
train_session.head()
# Out:
#                                                  sid  target
# 0  U6clt0UYaQB7vJQFmSWYymsAfwmT9SMhrm2oXQ8TC5M8mf...   False
# 1  0qRbLkxeOjeEo6CtxtB6VI8FNPt4Vl8niySzZLqSWiQOka...   False
# 2  cnCRGomfPqEWuhMZkA0RQfvTQiwVoyHXUqvqnPCutVouFO...   False
# 3  zBwrofN0r2ps9u/UCUS134SiZIqB+UgIEr0MZGHzksqR4f...   False
# 4  Kbr60r9eaX/ENOJ81R1YBxfwrEohoxyQI9Ma0fODsS+/XN...   False

# %%
train_tracking.columns
# Out:
# Index(['sid', 'type', 'query', 'nb_query_terms', 'rcount', 'pn', 'facets',
#        'products', 'dproducts', 'rh', 'rw', 'device', 'idcar', 'carproducts',
#        'sku', 'offerid', 'quantity', 'stype', 'sname', 'ff', 'oidcar',
#        'ocarproducts', 'oquery', 'orcount', 'ofacets', 'opn', 'odproducts',
#        'oproducts', 'siteid', 'duration', 'type_simplified'],
#       dtype='object')

# %%
df = train_tracking.head(200)

# %%
df.head()
# Out:
#                                                  sid      type query  \
# 0  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 1  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 2  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 3  xvmQh3WmJGKaplwGgHf4o1MNKg2/6IpkbKNh4nnwZibi3f...  CAROUSEL   NaN
# 4  KeKjpi6re4QRYxl76E8sLPJHxRCeapb4sb69s5hmPCV+Jn...        PA   NaN
#
#    nb_query_terms  rcount  pn facets products dproducts    rh  \
# 0             NaN     NaN NaN    NaN      NaN       NaN  1094
# 1             NaN     NaN NaN    NaN      NaN       NaN  1094
# 2             NaN     NaN NaN    NaN      NaN       NaN  1094
# 3             NaN     NaN NaN    NaN      NaN       NaN  1094
# 4             NaN     NaN NaN    NaN      NaN       NaN   875
#
#         ...         ocarproducts oquery orcount ofacets opn odproducts  \
# 0       ...                  NaN    NaN     NaN     NaN NaN        NaN
# ...

# %%
df[df['type_simplified'] == 'ADD_TO_BASKET']
# Out:
#                                                    sid  \
# 21   e2Qk4mY2coR7ccDjFb14arn512Jw7rKn9TF5QFOeoQw6Ct...
# 82   knWvEQl2pZ7FKq2MItMMj4xcgFT7Zu5ekEOh9UQl7BiwaQ...
# 101  knWvEQl2pZ7FKq2MItMMj4xcgFT7Zu5ekEOh9UQl7BiwaQ...
# 105  knWvEQl2pZ7FKq2MItMMj4xcgFT7Zu5ekEOh9UQl7BiwaQ...
# 191  WIdRXlIhBSsdTGZIgiqozX6KpwA/HptmC2Ume1eMCDfKB/...
#
#                        type                     query  nb_query_terms  rcount  \
# 21         ADD_TO_BASKET_LR                       NaN             NaN     0.0
# 82   ADD_TO_BASKET_CAROUSEL                       NaN             NaN     NaN
# 101        ADD_TO_BASKET_LR  LrTsBmFs+aWCLGbpllu3mA==             1.0   463.0
# 105        ADD_TO_BASKET_LR  M7CGVr9BnuzT2mAFNA6xCg==             4.0   447.0
# 191  ADD_TO_BASKET_CAROUSEL                       NaN             NaN     NaN
#
#       pn facets products dproducts   rh       ...         \
# 21   0.0    NaN      NaN       NaN  649       ...
# 82   NaN    NaN      NaN       NaN  655       ...
# ...

# %%
df[df['type'] == 'ADD_TO_BASKET_CAROUSEL']
# Out:
#                                                    sid  \
# 82   knWvEQl2pZ7FKq2MItMMj4xcgFT7Zu5ekEOh9UQl7BiwaQ...
# 191  WIdRXlIhBSsdTGZIgiqozX6KpwA/HptmC2Ume1eMCDfKB/...
#
#                        type query  nb_query_terms  rcount  pn facets products  \
# 82   ADD_TO_BASKET_CAROUSEL   NaN             NaN     NaN NaN    NaN      NaN
# 191  ADD_TO_BASKET_CAROUSEL   NaN             NaN     NaN NaN    NaN      NaN
#
#     dproducts   rh       ...         \
# 82        NaN  655       ...
# 191       NaN  955       ...
#
#                                           ocarproducts oquery orcount ofacets  \
# 82   [{'sku': '5BsZ9b6Vizdki7dvClF3gg==', 'offerid'...    NaN     NaN     NaN
# 191  [{'sku': 'yD4GsxD/ju5VpsnXfXl25+p6NPTGBfCKCRdX...    NaN     NaN     NaN
#
#     opn odproducts  oproducts                    siteid  \
# 82  NaN        NaN        NaN  cF8tnO1rK7fIBxVIs+AW4w==
# 191 NaN        NaN        NaN  cF8tnO1rK7fIBxVIs+AW4w==
#
#                       duration  type_simplified
# ...

# %%
df[df['type'] == 'ADD_TO_BASKET_LP']
# Out:
# Empty DataFrame
# Columns: [sid, type, query, nb_query_terms, rcount, pn, facets, products, dproducts, rh, rw, device, idcar, carproducts, sku, offerid, quantity, stype, sname, ff, oidcar, ocarproducts, oquery, orcount, ofacets, opn, odproducts, oproducts, siteid, duration, type_simplified]
# Index: []
#
# [0 rows x 31 columns]

# %%
df[df['type'] == 'ADD_TO_BASKET_LR']
# Out:
#                                                    sid              type  \
# 21   e2Qk4mY2coR7ccDjFb14arn512Jw7rKn9TF5QFOeoQw6Ct...  ADD_TO_BASKET_LR
# 101  knWvEQl2pZ7FKq2MItMMj4xcgFT7Zu5ekEOh9UQl7BiwaQ...  ADD_TO_BASKET_LR
# 105  knWvEQl2pZ7FKq2MItMMj4xcgFT7Zu5ekEOh9UQl7BiwaQ...  ADD_TO_BASKET_LR
#
#                         query  nb_query_terms  rcount   pn facets products  \
# 21                        NaN             NaN     0.0  0.0    NaN      NaN
# 101  LrTsBmFs+aWCLGbpllu3mA==             1.0   463.0  1.0    NaN      NaN
# 105  M7CGVr9BnuzT2mAFNA6xCg==             4.0   447.0  1.0    NaN      NaN
#
#     dproducts   rh       ...         ocarproducts  \
# 21        NaN  649       ...                  NaN
# 101       NaN  655       ...                  NaN
# 105       NaN  655       ...                  NaN
#
#                                            oquery orcount ofacets  opn  \
# 21   n3nVKaET596gn4ITKpOb5yzsLej2qyAcvWLFepzx+pw=  1797.0     NaN  8.0
# ...

# %%
df[df['type'] == 'ADD_TO_BASKET_LP']
# Out:
# Empty DataFrame
# Columns: [sid, type, query, nb_query_terms, rcount, pn, facets, products, dproducts, rh, rw, device, idcar, carproducts, sku, offerid, quantity, stype, sname, ff, oidcar, ocarproducts, oquery, orcount, ofacets, opn, odproducts, oproducts, siteid, duration, type_simplified]
# Index: []
#
# [0 rows x 31 columns]

# %%
df[df['type'] == 'ADD_TO_BASKET_PA']
# Out:
# Empty DataFrame
# Columns: [sid, type, query, nb_query_terms, rcount, pn, facets, products, dproducts, rh, rw, device, idcar, carproducts, sku, offerid, quantity, stype, sname, ff, oidcar, ocarproducts, oquery, orcount, ofacets, opn, odproducts, oproducts, siteid, duration, type_simplified]
# Index: []
#
# [0 rows x 31 columns]

# %%
df[df['type'] == 'ADD_TO_BASKET_SHOW_CASE']
# Out:
# Empty DataFrame
# Columns: [sid, type, query, nb_query_terms, rcount, pn, facets, products, dproducts, rh, rw, device, idcar, carproducts, sku, offerid, quantity, stype, sname, ff, oidcar, ocarproducts, oquery, orcount, ofacets, opn, odproducts, oproducts, siteid, duration, type_simplified]
# Index: []
#
# [0 rows x 31 columns]

# %%
productid_category.head()
# Out:
#                  product_id  category_product_id_level1  \
# 0  i1t4Uq+NqhB0O4d2J/jzCA==                     1387712
# 1  a0OxyFVArDl0UzhpmP1L5w==                          13
# 2  mQ+KVVCUfLKmb2Rlo/FT3A==                          22
# 3  KVg9N8j/cuLPkvIcSzYemw==                           5
# 4  N9mErkxf69NX7uuqysEWGA==                     2626413
#
#    category_product_id_level2  category_product_id_level3
# 0                     1388277                     1394791
# 1                          87                        6352
# 2                         527                        5945
# 3                          11                          40
# 4                     2626979                     2633494

# %%
from ast import literal_eval

python_dict = literal_eval(str(df.iloc[82]['ocarproducts']))

# %%
python_dict
# Out:
# [{'isinstock': True,
#   'offerid': '43AaXr8AZq195JDP/AWzVw==',
#   'pos': 1,
#   'rate': 3.0,
#   'rvoter': 3.0,
#   'sellerid': 'xYc0p0eqncEwfcO1gZGNlw==',
#   'sku': '5BsZ9b6Vizdki7dvClF3gg=='},
#  {'isinstock': True,
#   'offerid': 'A6xfAKgCr0ZqXE44mgFXtg==',
#   'pos': 2,
#   'rate': 4.0,
#   'rvoter': 11.0,
#   'sellerid': 'xYc0p0eqncEwfcO1gZGNlw==',
#   'sku': 'H2tNm2vEd+bj3emwsX99wA=='},
#  {'isinstock': True,
#   'offerid': 'o/jZHqCUpPMTF92LGD15rA==',
#   'pos': 3,
#   'rate': 4.0,
#   'rvoter': 19.0,
#   'sellerid': '0FwsA9GTC2pegaTy5CKKgA==',
#   'sku': '8zick48wa9tvOE7sra5aU+p6NPTGBfCKCRdXNRSP70U='},
#  {'isinstock': True,
#   'offerid': 'jJxCJt+Kh22Zkvt+5bv4JA==',
#   'pos': 4,
#   'rate': 4.0,
#   'rvoter': 8.0,
#   'sellerid': 'x3scN61z6qgsERfC61eeYg==',
#   'sku': 'Q6yQK8z+HfzKyw/P9BMcKQ=='},
#  {'isinstock': True,
#   'offerid': 'V8Jw06724YUhHAI47qxNfQ==',
#   'pos': 5,
#   'rate': 4.0,
#   'rvoter': 5.0,
#   'sellerid': 'xYc0p0eqncEwfcO1gZGNlw==',
# ...

# %%
productid_category
