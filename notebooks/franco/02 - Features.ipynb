# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from tqdm import tqdm, tqdm_notebook
from pathlib import Path
from collections import Counter
from sklearn.decomposition import PCA
from ast import literal_eval
sns.set()

DATA = Path('../../data')
RAW  = DATA/'raw'
PROCESSED = DATA/'processed'
SUBMISSIONS = DATA/'submissions'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%time
product           = pd.read_csv(RAW/'productid_category.csv', low_memory=False)
train_tracking    = pd.read_csv(RAW/'train_tracking.csv', low_memory=False)
test_tracking     = pd.read_csv(RAW/'test_tracking.csv', low_memory=False)
train_session     = pd.read_csv(RAW/'train_session.csv', low_memory=False)
test_session      = pd.read_csv(RAW/'random_submission.csv', low_memory=False)
# Out:
# CPU times: user 1min 9s, sys: 6.96 s, total: 1min 16s
# Wall time: 1min 16s

# %%
session_features = train_session.copy()

# %% [markdown]
# # Duration feature
# ### TOTAL_DURATION

# %%
# Convertir duration a total de segundos
def duration_to_seconds(train_tracking):
    train_tracking.duration = pd.to_timedelta(train_tracking.duration).dt.total_seconds()
    return train_tracking

def duration_feature(session_features, train_tracking):
    train_tracking = duration_to_seconds(train_tracking)
    durations = train_tracking.groupby('sid').duration.max().reset_index()
    durations.columns = ['sid', 'TOTAL_DURATION']
    session_features = pd.merge(session_features, durations, on='sid', how='left')
    return session_features

# %%
duration_to_seconds(train_tracking)
train_tracking.duration
# Out:
# 0           0.000000
# 1          11.179638
# 2          13.132756
# 3         137.397333
# 4           0.000000
# 5           3.571980
# 6          43.736337
# 7         193.467328
# 8         860.748909
# 9         861.640271
# 10      39220.444632
# 11          0.000000
# 12         22.974930
# 13         74.070494
# 14         89.935316
# 15        124.919148
# 16        172.222364
# 17        199.921949
# 18        220.535582
# 19        239.207941
# 20        331.216386
# 21        426.326788
# 22        433.759435
# 23        476.879169
# 24        500.808141
# 25        527.359679
# 26        601.352748
# 27        625.361456
# 28        642.594890
# 29          0.000000
#             ...
# 9970     2494.048306
# 9971        0.000000
# 9972       13.894872
# 9973       35.829504
# 9974      149.785943
# 9975      155.185702
# 9976        0.000000
# 9977       27.456191
# 9978       33.077170
# 9979       61.828305
# 9980       86.022902
# 9981       95.962380
# 9982      105.844270
# 9983     1392.396024
# 9984        0.000000
# 9985     1242.207719
# 9986     1260.761048
# 9987     1264.662385
# 9988     1301.691151
# 9989        0.000000
# 9990       18.013179
# 9991       89.916978
# 9992       90.906816
# 9993       92.532121
# 9994      151.645698
# 9995      206.468946
# 9996      214.174585
# 9997      218.707864
# 9998      280.213102
# 9999      313.425653
# Name: duration, Length: 10000, dtype: float64

# %%
durations = train_tracking.groupby('sid').duration.max().reset_index()
durations.columns = ['sid', 'TOTAL_DURATION']

# %%
durations
# Out:
#                                                       sid  TOTAL_DURATION
# 0       +++elmtsXqN289wWNi6auO1Fm7gyPkXmsKngig88cIqXDD...      214.537492
# 1       ++0tYP9PmT6jX9O1WjUhWd7w3hWV6xSRMBOdA7HMoBukKs...       65.059323
# 2       ++2CIH+Rnf2MBamibl+EPSMDTKmweZzRgeX/VDBussbBR8...      167.882281
# 133121  zzvjqPVlukinLS3T5mRrHdJJxv5nghyTwIpmNQ5YafIgbG...    24637.029061
# 133122  zzy2dn12kLs7VAHY4ZaXo7rlDRfZR6bb/Kd+NaHpw12Uet...       95.176004
#
# [133123 rows x 2 columns]

# %%
session_features = pd.merge(session_features, durations, on='sid', how='left')

# %%
session_features = duration_feature(session_features, train_tracking)
session_features
# Out:
#                                                     sid  target  \
# 0     U6clt0UYaQB7vJQFmSWYymsAfwmT9SMhrm2oXQ8TC5M8mf...   False
# 1     0qRbLkxeOjeEo6CtxtB6VI8FNPt4Vl8niySzZLqSWiQOka...   False
# 2     cnCRGomfPqEWuhMZkA0RQfvTQiwVoyHXUqvqnPCutVouFO...   False
# 3     zBwrofN0r2ps9u/UCUS134SiZIqB+UgIEr0MZGHzksqR4f...   False
# 4     Kbr60r9eaX/ENOJ81R1YBxfwrEohoxyQI9Ma0fODsS+/XN...   False
# 5     NsKSt1vreFt/tpUjhr2L4dYUlsaEpHiq2qsBMG6d+t+WtV...   False
# 6     7Rgtt5iDUSO+/FGfyIaTrWYDiNjF1KbULPrldFj78dX6JO...   False
# 7     L9OHLekz6vMT7t609Y6c3fUIJ2i5MKgdam8UOcCOJnDs+V...   False
# 8     PydsL5KNw3VBO0pgF6HhczwRONYLyAhUIgzYMQv3Vaj84H...   False
# 9     hLnY1trrWZhSv5dFqEZzBCPfvw6RI/vTzG1BrDpPuYvFjY...   False
# 10    QbsTV8hmOameibKor89/6AwKc8Q4hg9RIzyw78YR/cERee...   False
# 11    YO6LBndrqBsFQOHftNf6R07QXNkj5eg2MxI6RUWgZ9zRW7...   False
# 12    9R3ZqX18WlEI0LqZ/x2WA97E3VXpg+L4rFKONZ5ZAco66F...   False
# 13    NIW+cQkj9H53f3F9OdqkMG9JxWNu5x8rYgVAroTiaxeMWm...   False
# 14    qlkUZNG252GJk1oIV50JWsXPf4bwyJZmc781cgx3HLUOnn...   False
# 15    e/ZIqs+jNGW03kmCI943PizTzN6kFKjmieLxhCX9OPRitX...   False
# 16    GJ0WJ6zNCxanxod+PDkW2Sh7YrYUaB+HUksxZQebnSzqBM...   False
# 17    AVn5AiaU8xi21Zsbrkvs3glb6HJBOhFzL7AV84DIvzBPyB...   False
# 18    7KGyUrLek7IUxKWjwyIlcIc5NkYIHtRsH0rTWv7mde/Svr...   False
# 19    q72mnwMjoDA+GY9ZOyVauPKDhGfHIPSgLdm1cBHsV6Dx19...   False
# 20    BT67GtjRcdiek8Ou2SCRWkn64IGeoQ7JQxOCjZbxR3WKez...   False
# 21    4Ot1eWohdNr6c4KiGfZkVqH8NB9T8V3UvVZMAmlrnb6JK2...   False
# 22    czM5ijRqf6Vonj73Ia4hxGn5jvxXLMiDG4f41v/Z0CuV6J...   False
# 23    ag2UtQuD8urHns1fYpkHCkJAxiY/oWkMpkwe8ooDb2Pqdo...    True
# 24    iNWo7linoRAz+Nrh3xrQLe+Wp4BQsnYKFytujVdr0Q/uqA...   False
# 25    GvbuSuBTe/ZRV0Gj6XETCgN7jOLmuwYPWsSNdRhlGW4oT9...   False
# 9994  3qG17d77+0afkjvQzPrr90EIHirSDP5RqYCVfJGxzmjopg...   False
# 9995  luaO8jnogo/jCmVKnoky3cdTcfYaGmt/mLfjGpaivbOIWs...   False
# 9996  xrLK9jeefqch5FzKIF937fQTfSMSXAtB+eMQVWnj+v4FKC...   False
# 9997  og0fPPZbff47Hu8jAwMdpj4/cfyjkwiQuLofStK4QhgP2/...   False
# 9998  PB1PJIQpfDXkzOOTh4MmDLcvcsRRRF6Eb/TRDydRipsEs5...   False
# 9999  vgXG8iaoqQErl8Mne2NnOiUs9y+Kzj27Gmf1fLqJempCNf...   False
#
#       TOTAL_DURATION
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ...              ...
# 9970             NaN
# 9971             NaN
# 9972             NaN
# 9973             NaN
# 9974             NaN
# 9975             NaN
# 9976             NaN
# 9977             NaN
# 9978             NaN
# 9979             NaN
# 9980             NaN
# 9981             NaN
# 9982             NaN
# 9983             NaN
# 9984             NaN
# 9985             NaN
# 9986             NaN
# 9987             NaN
# 9988             NaN
# 9989    1.570000e-07
# 9990             NaN
# 9991             NaN
# 9992             NaN
# 9993             NaN
# 9994             NaN
# 9995             NaN
# 9996             NaN
# 9997             NaN
# 9998             NaN
# 9999             NaN
#
# [10000 rows x 3 columns]

# %% [markdown]
# # Main category features

# %%
def add_page(train_tracking):
    def extract_page(x):
        pages_types = ['_LR', '_PA', '_LP', '_CAROUSEL', '_SHOW_CASE']
        pages = ['CAROUSEL', 'PA', 'SEARCH', 'SHOW_CASE', 'LIST_PRODUCT']
        pages_map = [['PURCHASE_PRODUCT_UNKNOW_ORIGIN', 'UNKNOWN']]
        for pages_type in pages_types:
            if x.endswith(pages_type):
                return x[-len(pages_type)+1:]
        for page in pages:
            if x == page:
                return x
        for page_map in pages_map:
            if x == page_map[0]:
                return page_map[1]
        return '::' + x
    train_tracking['page'] = train_tracking.type.apply(extract_page)
    return train_tracking

def simplify_categories(product):
    counter1 = product.groupby('category_product_id_level1').size()
    counter1dict = counter1.to_dict()
    mapcat = {}
    for idx in counter1dict:
        if counter1dict[idx] > 10:
            mapcat[idx] = idx
        else:
            mapcat[idx] = 10e7
    product['cat1'] = product.category_product_id_level1.apply(lambda x: mapcat[x])
    return product

def convert_jsonproducts(train_tracking, column):
    def convert_json(x):
        if pd.isnull(x):
            return x
        else:
            return literal_eval(x)
    train_tracking['product_list'] = train_tracking[column].apply(convert_json)
    return train_tracking

# %%
print('Loading pages')
train_tracking = add_page(train_tracking)
print('Loading categories')
product = simplify_categories(product)
product = product.append({'product_id': 'Zw92hEmaaA7dQb2cgpn/Jg==', 'cat1': 100000000.0}, ignore_index=True)
product = product.append({'product_id': '7UPNQe/PpnKtw1Sz998sUup6NPTGBfCKCRdXNRSP70U=', 'cat1': 100000000.0}, ignore_index=True)
print('Loading catmap')
catmap = dict(zip(product.product_id, product.cat1))
# Out:
# Loading pages
# Loading categories
# Loading catmap

# %%
def cat_counter(prodlist):
    global product
    counter = {}
    for prod in prodlist:
        if not prod['sku'] in catmap:
            print('CANT FIND ' + prod['sku'])
            # print(prodlist)
            cat = 10e7
        else:
            cat = int(catmap[prod['sku']])
        if cat in counter:
            counter[cat] = counter[cat] + 1
        else:
            counter[cat] = 1
    return counter

def merge_counters(counters):
    merged = {}
    for counter in counters:
        merged = {**merged, **counter}
    return merged

# %% [markdown]
# ### ------- MAIN_CATEGORY_CAROUSEL -------

# %%
def main_cat_carousel(session_features):
    return session_features

# %% [markdown]
# ### MAIN_CATEGORY_PURCHASE

# %%
def main_cat_purchase(session_features):
    carousel = convert_jsonproducts(train_tracking[train_tracking.type=='PURCHASE_PRODUCT_CAROUSEL'].copy(), 'ocarproducts')
    carousel['prod_counter'] = carousel.product_list.apply(cat_counter)
    session_carousel = carousel.groupby('sid').prod_counter.agg(merge_counters).reset_index()
    
    lp = convert_jsonproducts(train_tracking[train_tracking.type=='PURCHASE_PRODUCT_LP'].copy(), 'products')
    lp['prod_counter'] = lp.product_list.apply(cat_counter)
    session_lp = lp.groupby('sid').prod_counter.agg(merge_counters).reset_index()
    
    return session_features

# %%
carousel = convert_jsonproducts(train_tracking[train_tracking.type=='PURCHASE_PRODUCT_CAROUSEL'].copy(), 'ocarproducts')

# %%
product.tail()
# Out:
#                                             product_id  \
# 10635916  nT4sUuBC/5jry7c276xuuup6NPTGBfCKCRdXNRSP70U=
# 10635917  vGDhDzugmY2Dx+dsJJ2q8ep6NPTGBfCKCRdXNRSP70U=
# 10635918  U/XDT/PYFx6TRxUVo3A6k+p6NPTGBfCKCRdXNRSP70U=
# 10635919                      Zw92hEmaaA7dQb2cgpn/Jg==
# 10635920  7UPNQe/PpnKtw1Sz998sUup6NPTGBfCKCRdXNRSP70U=
#
#           category_product_id_level1  category_product_id_level2  \
# 10635916                    574400.0                    574964.0
# 10635917                   5024889.0                   5025466.0
# 10635918                   5103804.0                   5104370.0
# 10635919                         NaN                         NaN
# 10635920                         NaN                         NaN
#
#           category_product_id_level3         cat1
# 10635916                    581475.0  100000000.0
# 10635917                   5031966.0  100000000.0
# 10635918                   5110887.0  100000000.0
# 10635919                         NaN  100000000.0
# 10635920                         NaN  100000000.0

# %%
def find_main_cat(prodlist):
    global product
    counter = {}
    for prod in prodlist:
        if not prod['sku'] in catmap:
            print(prodlist)
            continue
        cat = int(catmap[prod['sku']])
        if cat in counter:
            counter[cat] = counter[cat] + 1
        else:
            counter[cat] = 1
    evaluate = Counter(counter)
    return evaluate.most_common(1)[0][0]

# find_main_cat(carousel.iloc[0].product_list)
# product.columns
carousel['prod_counter'] = carousel.product_list.apply(cat_counter)
session_carousel = carousel.groupby('sid').prod_counter.agg(merge_counters)

# %%
lp = convert_jsonproducts(train_tracking[train_tracking.type=='PURCHASE_PRODUCT_LP'].copy(), 'products')
lp['prod_counter'] = lp.product_list.apply(cat_counter)
session_lp = lp.groupby('sid').prod_counter.agg(merge_counters).reset_index()

# %%
lr = convert_jsonproducts(train_tracking[train_tracking.type=='PURCHASE_PRODUCT_LR'].copy(), 'oproducts')
lr['prod_counter'] = lr.product_list.apply(cat_counter)
session_lr = lr.groupby('sid').prod_counter.agg(merge_counters).reset_index()
# Out:
# CANT FIND KwvglcLn/9rrtihM2P9oz+p6NPTGBfCKCRdXNRSP70U=
# CANT FI
p6NPTGBfCKCRdXNRSP70U=
# CANT FIND 0Z8Ja3TQHtuijAIduzigEOp6NPTGBfCKCRdXNRSP70U=
# CANT FIND Fr5kMi+uwd8/jmGDG9OtTOp6NPTGBfCKCRdXNRSP70U=
# CANT FIND 0Z8Ja3TQHtuijAIduzigEOp6NPTGBfCKCRdXNRSP70U=

# %% [markdown]
# ### MAIN_CATEGORY_CART

# %% [markdown]
# # Cantidad de productos comprados

# %%
quants = train_tracking[(train_tracking.type=='PURCHASE_PRODUCT_UNKNOWN_ORIGIN') | (train_tracking.type=='PURCHASE_PRODUCT_SHOW_CASE')\
                   | (train_tracking.type=='PURCHASE_PRODUCT_PA') | (train_tracking.type=='PURCHASE_PRODUCT_LR')\
                   | (train_tracking.type=='PURCHASE_PRODUCT_LP') | (train_tracking.type=='PURCHASE_PRODUCT_CAROUSEL')].groupby('sid').quantity.sum().reset_index()

# %%
# sns.distplot(quants)
quants.columns = ['sid', 'PURCHASED_PRODUCTS']
quants
# Out:
#                                                     sid  PURCHASED_PRODUCTS
# 0     +0Vh/Trjzcshzuq1XXjfUhr9EJHAll+V/yKuV/hhWQhNpn...                 1.0
# 1     +3HJmV33aSPd7dF3hswIRCVWMudpCQOP4zf6JEsmOshW6G...                 1.0
# 2     +A91LKDkR6SdIIgFkTFHG7A2TMtBIM3tlnD7svGWYfpIQS...                 1.0
# 3     +BYtKgJYRuo7/IhqaOoV2Oxlkf4JYjYyLtX1up/oDZnGIp...                 3.0
# 4     +C1il78kgxdQt6W/usx6LdbCSdPNmI9b4n4Kg1/WwFamjW...                 1.0
# 5     +CUMGswW8k1NfC0xw7kTO8P/zegEWNqHRnzu4IxNQul0/g...                 1.0
# 6     +FeBcR2+niL8pkSjFvgSKebwwIW7CwbJEr6V8mLird1jno...                 1.0
# 7     +Fv7Kv71hyMAvMEqsvm594k/aV6/nnM3lkwjuETVaCfvo0...                 1.0
# 8     +Giwr/L8m+C8Z6js5JrkSpYOskYVRI2qr712mQNauYHN1X...                 1.0
# 9     +IdqwfISPjEbO9bxokyFK1KOgDA3ta0cu6uSy1Dld0w9Gk...                 1.0
# 10    +VGG2+L0GPsl0/GlUIa7NsZFMToEWGIVEG0OkEou7Buiv0...                 1.0
# 11    +WAQB7pxma1O5AEExeC0PMy+cEJPez0et892LS9DwIa5AG...                 1.0
# 12    +Z6wrXmkca9cGV/FiBDgc0dvGltWhtfuqZ4IuzQcoi4W5k...                 1.0
# 13    +ayK+zIPytlirjHt5Eqp22s6LKwUQAd33yG36lWzPifQby...                 1.0
# 14    +cwfCbH5uvjgsrvY3OhkuOTuZ0IzfBQm9IwnHa5M6k186t...                 1.0
# 15    +dMKGLSWx2MELDQn3qkddWELgPqveZ6BjcFT6N+0InvmN+...                 1.0
# 16    +fE7/F9RTM4ZaC3KRRjKT11fvxVk+lbMVlv/gsQ6sPyJ17...                 2.0
# 17    +g9RzqDFmICtwQDHtsieOj83n0TRQlgTl3BdFybKp4T2Ls...                 3.0
# 18    +lNEzR9VicKlbzb2g8ibvCj8wEMJU6d0JPQ2cIL5WAWPdP...                 2.0
# 19    +nFJh78smEkBOdGlMk/SNTsV3XR5DBzUqAbsGv7tiII6g8...                 1.0
# 1607  zHKCpK3Vu+L6h0o3pefF8wMRC5AnQxXKteykS9qKKNvB+e...                 1.0
# 1608  zJaY9eT44aEPbRLX599+K5rtLbfPq3ed8zZ6bTd14A71TV...                 1.0
# 1609  zKqgte+HQb/pnF+geSMp0xhU7VLbpSpHJPKZcEnibnE7Fl...                 1.0
# 1610  zUaqAzAoI9Q57vndtmCncCkFvRdGMzb4rIY5durxlbZ64c...                 5.0
# 1611  zaw33fFhAAvN20Y4nv5uzVPUXvFVAbC9w5nc8RLd6dMcAN...                 1.0
# 1612  zbw4u/JGMvSQC4PK/+8OOO+8h3qYr+CHgFIR/bZdzXQ9Gd...                 1.0
# 1613  zfmdhNZKOHKZymXL2qWSeIKifZ1+RrSLaRUZ8vlE+yKwCP...                 3.0
# 1614  zhd+y73C9wMZe8hH6oH7Cecpp/YWdaCzJwTvlktpNgB2v5...                 1.0
# 1615  zlatDTIqpx9a1kzUKPEaZAi5XcZKkeuvmcNWYYJ3XgrWF8...                 3.0
# 1616  zs3p5bPb5aGiXEGuG8hFx0Z4j6RJum8UUbKhy4RBiwpAwZ...                 1.0
# 1617  zuK1lCz13WCH7WLRcfysuejZ3TbgalLoNafgylAe5QlXi2...                 1.0
# 1618  zz5gP4mWBxeFYBCiKkzw68qfnTyHgsuzH5B0ThOpFpOkBY...                 1.0
# 1619  zzvjqPVlukinLS3T5mRrHdJJxv5nghyTwIpmNQ5YafIgbG...                 1.0
#
# [1620 rows x 2 columns]

# %%
def purchased_products(session_features, train_tracking):
    quants = train_tracking[(train_tracking.type=='PURCHASE_PRODUCT_UNKNOWN_ORIGIN') | (train_tracking.type=='PURCHASE_PRODUCT_SHOW_CASE')\
                   | (train_tracking.type=='PURCHASE_PRODUCT_PA') | (train_tracking.type=='PURCHASE_PRODUCT_LR')\
                   | (train_tracking.type=='PURCHASE_PRODUCT_LP') | (train_tracking.type=='PURCHASE_PRODUCT_CAROUSEL')].groupby('sid').quantity.sum().reset_index()
    quants.columns = ['sid', 'PURCHASED_PRODUCTS']
    session_features = pd.merge(session_features, quants, on='sid', how='left')
    return session_features

purchased_products(session_features, train_tracking)
# Out:
#                                                       sid  target  \
# 0       U6clt0UYaQB7vJQFmSWYymsAfwmT9SMhrm2oXQ8TC5M8mf...   False
# 1       0qRbLkxeOjeEo6CtxtB6VI8FNPt4Vl8niySzZLqSWiQOka...   False
# 2       cnCRGomfPqEWuhMZkA0RQfvTQiwVoyHXUqvqnPCutVouFO...   False
# 3       zBwrofN0r2ps9u/UCUS134SiZIqB+UgIEr0MZGHzksqR4f...   False
# 4       Kbr60r9eaX/ENOJ81R1YBxfwrEohoxyQI9Ma0fODsS+/XN...   False
# 5       NsKSt1vreFt/tpUjhr2L4dYUlsaEpHiq2qsBMG6d+t+WtV...   False
# 6       7Rgtt5iDUSO+/FGfyIaTrWYDiNjF1KbULPrldFj78dX6JO...   False
# 7       L9OHLekz6vMT7t609Y6c3fUIJ2i5MKgdam8UOcCOJnDs+V...   False
# 133101  GTt3HBu3svh5Jq+mWfkH1w5jIvqXQIlyk2cWQOeI+k0Qoz...   False
# 133102  o+z7+s8HAAa1FKkHH4w0KBPxfpkbzuGTUWNdNrAQhEgccq...   False
# 133103  SGSENh1tC/S+oDj8t5eNwJbd8Wqp8zYYekSc08tqKrkagC...   False
# 133104  3aDeB1cIwI/6sIqUjAt3u6lURUPiiiNUKgzeZmWyS6Latp...   False
# 133105  NZ2uu2Z1VPctfNIeTwKc35zb5p8Z0cFDuQxi5s4VIwkIWW...   False
# 133106  d1/4wn7g3asqujYEh4ciiznsur4LT7Ec3mDyOrTiYrKv/i...   False
# 133107  FE3psh11c/g0MNRdPhNfkWjcemISNqY5mrCicyBOqzryoB...   False
# 133108  7vzia4M1Ks8S+1MwCVBgfG8NpNPSeTrzWvHdWh7OAGW9Zj...   False
# 133109  8BWaIUo5/oijXAFzrtJJDiDlrPmQr9ktT9+Z92brpYZnB7...   False
# 133110  k1HbvAnGvJbzyhMS7DGmJ/n98SwrKEtLtAANsnEhvyWinS...    True
# 133111  Anzb/k/I9Zd9YOwdd2TGc3jSQ7Afc8B1/s5gO4trN3CDxl...   False
# 133112  xOprHNxcn1eZk90pfKzfeU5KsORNDguHjEnNJ/3rX3i6UN...   False
# 133113  VRilk6xAurXYovfWvfQtaFHTZbNqozPgXAVNwO8e2qW6l5...   False
# 133114  gRxbjexcCVLxw7WC5jjsTNW6M7rNqTyyz9jc9MwMv6T6Z2...   False
# 133115  oaN+Q1QKQ66y6cCZWVU6SXBg5jadHJLeXEmoro5LrfXaOa...   False
# 133116  6IZ+1BaAhVtuBEFkhYj0b8tS3tAPj20dTRuZcBDgnW3Cq2...   False
# 133117  lc55wUbmtke+Qrb8JvoJnkcsZCA1soDcc5k+Vhqqvg2/kN...   False
# 133118  LWJ6nMa7pFpJhPUjGHFFyo8f7fnqY/AeFQJt2v0wUy1ylP...   False
# 133119  M8CeecxedwFKQUZCZEDAcF4qlAOGB8OLNZl+W9vjcrrXTB...   False
# 133120  Ehaid2NT3CW/OwReQiiG7xQpYzni9zFOGfBihuOqzk/z8J...   False
# 133121  sy0R6iRSfZzPExOfsQeNVsZjQW2MzB+NRTi9DhPA1StL3j...   False
# 133122  BTLBdKXorXsThJ4+fYRLGRapqHICtZMwvGInO2vo/5yqbW...    True
#
#         PURCHASED_PRODUCTS
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# ...                    ...
# 133093                 NaN
# 133094                 NaN
# 133095                 NaN
# 133096                 NaN
# 133097                 NaN
# 133098                 NaN
# 133099                 NaN
# 133100                 NaN
# 133101                 NaN
# 133102                 NaN
# 133103                 NaN
# 133104                 NaN
# 133105                 NaN
# 133106                 NaN
# 133107                 NaN
# 133108                 NaN
# 133109                 NaN
# 133110                 NaN
# 133111                 NaN
# 133112                 NaN
# 133113                 NaN
# 133114                 NaN
# 133115                 NaN
# 133116                 NaN
# 133117                 NaN
# 133118                 NaN
# 133119                 NaN
# 133120                 NaN
# 133121                 NaN
# 133122                 NaN
#
# [133123 rows x 3 columns]
